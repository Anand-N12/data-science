# %%
''' accessed by index value '''
import numpy as np

a = np.array([1,2,3,4,5])
print(np.argmax(a))
# Out:
# 4

# %%
print(np.argmin(a))
# Out:
# 0

# %%
'''np.where() finds the positions (indexes) where a condition is true.'''
print(np.where(a>3))
# Out:
# (array([3, 4]),)

# %%
print(np.cumsum(a))
# Out:
# [ 1  3  6 10 15]

# %%
r=np.random.randint(1,20,15)
print(r)
# Out:
# [ 1 16 14  8 14 16  9 16 13 10 19 19  3  9 18]

# %%
a=np.array([1,2,3,4,5])
b=np.array([6,7,8,9,10])
print(np.corrcoef(a,b))
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
a=np.array([1,2,3,4,5])
b=np.array([10,9,8,7,6])
print(np.corrcoef(a,b))
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
a=np.array([1,2,3,4,5])
b=np.array([60,71,88,9,10])
print(np.corrcoef(a,b))
# Out:
# [[ 1.         -0.70788944]
#  [-0.70788944  1.        ]]

# %%
a=np.array([1,2,3,4,5])
np.save("ad.npy",a)
print(np.load("ad.npy"))
# Out:
# [1 2 3 4 5]
