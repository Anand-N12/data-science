# %%
''' accessed by index value '''
import numpy as np

a = np.array([1,2,3,4,5])
print(np.argmax(a))
# Out:
# 4

# %%
print(np.argmin(a))
# Out:
# 0

# %%
'''np.where() finds the positions (indexes) where a condition is true.'''
print(np.where(a>3))
# Out:
# (array([3, 4]),)

# %%
print(np.cumsum(a))
# Out:
# [ 1  3  6 10 15]

# %%
r=np.random.randint(1,20,15)
print(r)
# Out:
# [ 6 13  4 11 10 17  5 12 12 11  5  6  1 16 14]

# %%
a=np.array([1,2,3,4,5])
b=np.array([6,7,8,9,10])
print(np.corrcoef(a,b))
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
a=np.array([1,2,3,4,5])
b=np.array([10,9,8,7,6])
print(np.corrcoef(a,b))
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
a=np.array([1,2,3,4,5])
b=np.array([60,71,88,9,10])
print(np.corrcoef(a,b))
# Out:
# [[ 1.         -0.70788944]
#  [-0.70788944  1.        ]]

# %%
a=np.array([1,2,3,4,5])
np.save("ad.npy",a)
print(np.load("ad.npy"))
# Out:
# [1 2 3 4 5]

# %%
a=np.array([1,2,3,4,5])
print(a[2:4])
# Out:
# [3 4]

# %%
print(a[2:])
# Out:
# [3 4 5]

# %%
print(a[:3])
# Out:
# [1 2 3]

# %%
print(a[:-3])
# Out:
# [1 2]

# %%
print(a[-3:])
# Out:
# [3 4 5]

# %%
Arr=np.array([[1,2,3,4],[3,4,5,6],[7,8,9,2]])
print(Arr[0:1,1:3])
# Out:
# [[2 3]]

# %%
Arr=np.array([[1,2,3,4],[3,4,5,6],[7,8,9,2]])
print(Arr[0:2,1:2])
# Out:
# [[2]
#  [4]]

# %%
print(Arr[:,1:2])
# Out:
# [[2]
#  [4]
#  [8]]

# %%
print(Arr[:,::2])
# Out:
# [[1 3]
#  [3 5]
#  [7 9]]

# %%
import pandas as pd

# %%
c=pd.read_csv("ad.csv/product.csv")
c
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
c=pd.read_csv("product.csv")
c
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
d={
    "name":["anand","balu","raj"],
    "age":[25,26,24]
}
d
# Out:
# {'name': ['anand', 'balu', 'raj'], 'age': [25, 26, 24]}

# %%
j=pd.DataFrame(d)
j
# Out:
#     name  age
# 0  anand   25
# 1   balu   26
# 2    raj   24

# %%
f=j.to_csv("family.csv")

# %%
d=pd.read_csv("family.csv")
d
# Out:
#    Unnamed: 0   name  age
# 0           0  anand   25
# 1           1   balu   26
# 2           2    raj   24

# %%
print(d["name"],d["age"])
# Out:
# 0    anand
# 1     balu
# 2      raj
# Name: name, dtype: str 0    25
# 1    26
# 2    24
# Name: age, dtype: int64

# %%
print(d["age"],d["name"])
# Out:
# 0    25
# 1    26
# 2    24
# Name: age, dtype: int64 0    anand
# 1     balu
# 2      raj
# Name: name, dtype: str

# %%
print(d.loc[0:1,["name","age"]])
# Out:
#     name  age
# 0  anand   25
# 1   balu   26

# %%
print(d.loc[0:2,["name","age"]])
# Out:
#     name  age
# 0  anand   25
# 1   balu   26
# 2    raj   24

# %%
print(d.loc[:,"age"])
# Out:
# 0    25
# 1    26
# 2    24
# Name: age, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("customer.csv")
data
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
firstname=data["First Name"]
country=data["Country"]
firstname
# Out:
# 0       Sheryl
# 1      Preston
# 2          Roy
# 3        Linda
# 4       Joanna
#         ...
# 95        Karl
# 96        Lynn
# 97        Fred
# 98      Yvonne
# 99    Clarence
# Name: First Name, Length: 100, dtype: str

# %%
plt.scatter(firstname,country)
plt.title("FirstName vs Country")
plt.xlabel("firstname")
plt.ylabel("country")
plt.show()

# %%
import pandas as pd
scam=pd.read_csv("enterprise-customers.csv")
scam
# Out:
#     Index Customer ID                   Company Name  \
# 0       1  0RCCEXIyls  Bishop, Castaneda and Hopkins
# 1       2  uz8kOU9hlo               Gonzales-Barrera
# 2       3  2trtAQswcK  Watson, Chandler and Richmond
# 3       4  0R64SXxBYF                      Ho-Pierce
# 4       5  7Ecag6Vo3x                   Hamilton LLC
# ..    ...         ...                            ...
# 95     96  0TSB0IScYm                     Barron Ltd
# 96     97  KcLrJQNGJg                Herman-Galloway
# 97     98  pMtD1oyxeE                     Weeks-Kidd
# 98     99  i5a1Wftb4N                      Short PLC
# 99    100  CSjsnoC3aD                  Haney-Burgess
#
#    Primary Contact First Name Primary Contact Last Name  \
# 0                        Mike                  Sullivan
# 1                      Edward               Christensen
# 2                       Kerri                    Holmes
# 3                       Carly                 Mccormick
# ...

# %%
plt.plot(scam["Support Level"],scam["Customer Since"],color="red")
plt.title("support level vs Customer since")
plt.xlabel("SUPPORT LEVEL")
plt.ylabel("CUTOMER SINCE")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#monthly profit
months=np.array(['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'])
income=np.array([50,51,43,45,12,66,34,24,29,30,44,21])
plt.plot(months,income,color='blue',marker='o')
# plt.title("MONTHLY PROFIT")
# plt.xlabel("MONTH")
# plt.ylabel("INCOME")
# plt.show()
